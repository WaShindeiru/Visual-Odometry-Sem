# %% [markdown]
# # Visual Odometry

# %% [markdown]
# ### LightGlue

# %%
# !git clone https://github.com/WaShindeiru/Visual-Odometry-Sem
# Out:
# Cloning into 'Visual-Odometry-Sem'...
# remote: Enumerating objects: 236, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 236 (delta 0), reused 1 (delta 0), pack-reused 233 (from 1)
# Receiving objects: 100% (236/236), 181.74 MiB | 21.45 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Updating files: 100% (161/161), done.

# %%
# !mv Visual-Odometry-Sem/* .

# %%
from tools_final.show import *

# %%
# %matplotlib inline

# %%
path = "LightGlue/results/kitti_02+2025-06-01_00:36:04"
plot_s3_timestamp(path + "/groundtruth_se3_aligned.txt")
