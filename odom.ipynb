# %% [markdown]
# # Visual Odometry

# %% [markdown]
# ### LightGlue

# %%
# !git clone https://github.com/WaShindeiru/Visual-Odometry-Sem
# Out:
# Cloning into 'Visual-Odometry-Sem'...
# remote: Enumerating objects: 297, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 297 (delta 24), reused 40 (delta 14), pack-reused 233 (from 1)
# Receiving objects: 100% (297/297), 182.53 MiB | 11.98 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# Updating files: 100% (164/164), done.

# %%
# !mv Visual-Odometry-Sem/* .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from tools_final.show import *
from tools_final.evaluate import evaluate_trajectories

# %% [markdown]
# ## KITTI Dataset 02 Trajectory

# %%
path = "LightGlue/results/kitti_02+2025-06-01_00:36:04"
file_path = path + "/groundtruth_se3_aligned.txt"
plot_s3_timestamp(file_path)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_se3_timestamp_2d(file_path)

# %%
plot_s3_timestamp_estimated_groundtruth_one_ax(path + "/groundtruth_se3_aligned_removed.txt", path + "/results_se3_aligned_removed.txt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_s3_timestamp_estimated_groundtruth_one_ax(path + "/groundtruth_se3_aligned_removed_shifted.txt", path + "/results_se3_aligned_removed_shifted_scaled.txt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_s3_timestamp_estimated_groundtruth_one_ax(path + "/groundtruth_se3_aligned_removed_shifted.txt", path + "/results_se3_aligned_removed_shifted_scaled_rotated.txt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_s3_timestamp_estimated_groundtruth_2d(path + "/groundtruth_se3_aligned_removed_shifted.txt", path + "/results_se3_aligned_removed_shifted_scaled_rotated.txt")

# %%
evaluate_trajectories(
      est_input_path=path + "/results_se3_aligned_removed.txt",
      gt_input_path=path + "/groundtruth_se3_aligned_removed.txt",
      display=True,
      save=False,
      figure_path=None,
      mean_path=path + "/median.txt",
      log_scale=False,
      threshold=None,
      save_error=False,
      save_error_path=None
   )
# Out:
# Translation error mean: 1.6323795208936647
# Rotation error mean: 0.1190220181179597

# %% [markdown]
# ## KITTI Dataset 06 Trajectory

# %%
path = "LightGlue/results/kitty_06+2025-05-31_22:46:49"
file_path = path + "/groundtruth_se3_aligned.txt"
plot_s3_timestamp(file_path)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_se3_timestamp_2d(file_path)

# %%
plot_s3_timestamp_estimated_groundtruth_one_ax(path + "/groundtruth_se3_aligned_removed.txt", path + "/results_se3_aligned_removed.txt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_s3_timestamp_estimated_groundtruth_one_ax(path + "/groundtruth_se3_aligned_removed_shifted.txt", path + "/results_se3_aligned_removed_shifted_scaled.txt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_s3_timestamp_estimated_groundtruth_one_ax(path + "/groundtruth_se3_aligned_removed_shifted.txt", path + "/results_se3_aligned_removed_shifted_scaled_rotated.txt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_s3_timestamp_estimated_groundtruth_2d(path + "/groundtruth_se3_aligned_removed_shifted.txt", path + "/results_se3_aligned_removed_shifted_scaled_rotated.txt")

# %%
evaluate_trajectories(
      est_input_path=path + "/results_se3_aligned_removed.txt",
      gt_input_path=path + "/groundtruth_se3_aligned_removed.txt",
      display=True,
      save=False,
      figure_path=None,
      mean_path=path + "/median.txt",
      log_scale=False,
      threshold=None,
      save_error=False,
      save_error_path=None
   )
# Out:
# Translation error mean: 2.0867228154976822
# Rotation error mean: 0.11496863379497098
